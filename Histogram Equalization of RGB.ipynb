# %%
from google.colab import drive
drive.mount('/content/drive/')

path = '/content/drive/MyDrive/Computer Vision Module/Histogram Equalization with RGB/AllamaIqbalTomb2072016.jpg'
# Out:
# Mounted at /content/drive/

# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np

# %%
img = cv2.imread(path)

img_yuv = cv2.cvtColor(img, cv2.COLOR_BGR2YUV)

# equalize the histogram of the Y channel
img_yuv[:,:,0] = cv2.equalizeHist(img_yuv[:,:,0])

# convert the YUV image back to RGB format
img_output = cv2.cvtColor(img_yuv, cv2.COLOR_YUV2BGR)

cv2_imshow(img)
print('Original Image')
cv2_imshow(img_output)
print('Output')
# Out:
# <PIL.Image.Image image mode=RGB size=710x462 at 0x7F02F58BA890>
# Original Image
# <PIL.Image.Image image mode=RGB size=710x462 at 0x7F02F58BA350>
# Output
